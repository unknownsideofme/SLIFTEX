# %%
import pandas as pd
import numpy as np
import pickle 
import os

# %%
# Step 1: Open the file in read-binary mode
with open('data.pkl', 'rb') as file:
    # Step 2: Load the data from the file
    data = pickle.load(file)

# Now, `data` contains the deserialized Python object
print(data)
# Out:
# 0        JAN JAGRAN TIMES
# 1        JAGRAN CITY PLUS
# 2         SAMPURNA JAGRAN
# 3           DAINIK JAGRAN
# 4           VISHWA JAGRAN
#                ...
# 21394        KAIWART AWAZ
# 21395     SARBAHARAR AWAZ
# 21396      SHRAMIKER AWAZ
# 21397          SOBAR AWAZ
# 21398        AWAZ AAP TAK
# Name: Title Name, Length: 10790, dtype: object

# %%
data = pd.DataFrame(data)
data = data.drop_duplicates().dropna()

# %%
data.rename(columns={'Title Name': 'original'}, inplace=True)

data['title'] = data['original'].str.lower().apply(lambda x: ' '.join(sorted(x.split())))

# %%
data['title'] = data['title'].str.lower()

# %%
data
# Out:
#                original             title
# 0      JAN JAGRAN TIMES  jagran jan times
# 1      JAGRAN CITY PLUS  city jagran plus
# 2       SAMPURNA JAGRAN   jagran sampurna
# 3         DAINIK JAGRAN     dainik jagran
# 4         VISHWA JAGRAN     jagran vishwa
# ...                 ...               ...
# 21394      KAIWART AWAZ      awaz kaiwart
# 21395   SARBAHARAR AWAZ   awaz sarbaharar
# 21396    SHRAMIKER AWAZ    awaz shramiker
# 21397        SOBAR AWAZ        awaz sobar
# 21398      AWAZ AAP TAK      aap awaz tak
#
# [10790 rows x 2 columns]

# %%
from dotenv import load_dotenv
load_dotenv()
import os
api_key = os.getenv("PINECONE_API_KEY2")

# %%
import nltk
nltk.download('stopwords' )
nltk.download('punkt' )
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Debanjan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Debanjan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(data['title'])

# %%
def to_sparse_dict(row):
    return {
        "indices": row.indices.tolist(),
        "values": row.data.tolist()
    }

records = []
for i in range(X.shape[0]):
    sparse_vec = to_sparse_dict(X[i])
    metadata = {
        "title": data.iloc[i]["title"],
        "original": data.iloc[i]["original"]
    }
    record = {
        "id": f"id-{i}",
        "sparse_values": sparse_vec,
        "metadata": metadata
    }
    records.append(record)

# %%
records
# Out:
# [{'id': 'id-0',
#   'sparse_values': {'indices': [3204, 3268, 7687],
#    'values': [0.6341746948410293, 0.7536105134968789, 0.17289780325457538]},
#   'metadata': {'title': 'jagran jan times', 'original': 'JAN JAGRAN TIMES'}},
#  {'id': 'id-1',
#   'sparse_values': {'indices': [3204, 1477, 5587],
#    'values': [0.46269645209364696, 0.6010823487385641, 0.6516225926522825]},
#   'metadata': {'title': 'city jagran plus', 'original': 'JAGRAN CITY PLUS'}},
#  {'id': 'id-2',
#   'sparse_values': {'indices': [3204, 6519],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran sampurna', 'original': 'SAMPURNA JAGRAN'}},
#  {'id': 'id-3',
#   'sparse_values': {'indices': [3204, 1683],
#    'values': [0.5589070513561661, 0.829230310555732]},
#   'metadata': {'title': 'dainik jagran', 'original': 'DAINIK JAGRAN'}},
#  {'id': 'id-4',
#   'sparse_values': {'indices': [3204, 8196],
#    'values': [0.5717589523626054, 0.8204216601194876]},
#   'metadata': {'title': 'jagran vishwa', 'original': 'VISHWA JAGRAN'}},
#  {'id': 'id-5',
#   'sparse_values': {'indices': [3204, 3839],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'jagran kishan', 'original': 'KISHAN JAGRAN'}},
#  {'id': 'id-6',
#   'sparse_values': {'indices': [3204, 1833, 4999],
#    'values': [0.49912664770757703, 0.7612337088221797, 0.4139997948079508]},
#   'metadata': {'title': 'dev jagran news', 'original': 'DEV JAGRAN NEWS'}},
#  {'id': 'id-7',
#   'sparse_values': {'indices': [3204, 1683, 6105, 6604],
#    'values': [0.36305135212776773,
#     0.5386462467097052,
#     0.4402382987399797,
#     0.6198743235094315]},
#   'metadata': {'title': 'dainik jagran rashtriya sanskaran',
#    'original': 'DAINIK JAGRAN RASHTRIYA SANSKARAN'}},
#  {'id': 'id-8',
#   'sparse_values': {'indices': [3204, 3268],
#    'values': [0.6438715487491371, 0.7651336018705409]},
#   'metadata': {'title': 'jagran jan', 'original': 'JAN JAGRAN'}},
#  {'id': 'id-9',
#   'sparse_values': {'indices': [3204, 8115],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'jagran vidya', 'original': 'VIDYA JAGRAN'}},
#  {'id': 'id-10',
#   'sparse_values': {'indices': [3204, 3296],
#    'values': [0.5483239297621362, 0.8362660270812201]},
#   'metadata': {'title': 'jagran janhit', 'original': 'JANHIT JAGRAN'}},
#  {'id': 'id-11',
#   'sparse_values': {'indices': [3204, 7947],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'jagran uttrakhand', 'original': 'UTTRAKHAND JAGRAN'}},
#  {'id': 'id-12',
#   'sparse_values': {'indices': [3204, 7837],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'jagran uday', 'original': 'JAGRAN UDAY'}},
#  {'id': 'id-13',
#   'sparse_values': {'indices': [3204, 6404],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'jagran sahakar', 'original': 'SAHAKAR JAGRAN'}},
#  {'id': 'id-14',
#   'sparse_values': {'indices': [3204, 3895],
#    'values': [0.5351380348041863, 0.8447646321348411]},
#   'metadata': {'title': 'jagran krishi', 'original': 'KRISHI JAGRAN'}},
#  {'id': 'id-15',
#   'sparse_values': {'indices': [3204, 3895],
#    'values': [0.5351380348041863, 0.8447646321348411]},
#   'metadata': {'title': 'jagran krishi m.a.c.',
#    'original': 'M.A.C. KRISHI JAGRAN'}},
#  {'id': 'id-16',
#   'sparse_values': {'indices': [3204, 6447],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran sakhi', 'original': 'JAGRAN SAKHI'}},
#  {'id': 'id-17',
#   'sparse_values': {'indices': [3204, 3353],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran jat', 'original': 'JAT JAGRAN'}},
#  {'id': 'id-18',
#   'sparse_values': {'indices': [3204, 985],
#    'values': [0.6559522655488579, 0.754802375010387]},
#   'metadata': {'title': 'bharat jagran', 'original': 'BHARAT JAGRAN'}},
#  {'id': 'id-19',
#   'sparse_values': {'indices': [3204, 2690],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'gurjar jagran', 'original': 'GURJAR JAGRAN'}},
#  {'id': 'id-20',
#   'sparse_values': {'indices': [3204, 7900],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran upbhoktha', 'original': 'UPBHOKTHA JAGRAN'}},
#  {'id': 'id-21',
#   'sparse_values': {'indices': [3204, 5587, 3445],
#    'values': [0.4181622376939119, 0.58890436752309, 0.6916154920756543]},
#   'metadata': {'title': 'jagran josh plus', 'original': 'JAGRAN JOSH PLUS'}},
#  {'id': 'id-22',
#   'sparse_values': {'indices': [3204, 3268, 46],
#    'values': [0.4332556572633739, 0.5148518554931072, 0.7397412401269695]},
#   'metadata': {'title': 'aandolan jagran jan',
#    'original': 'JAN JAGRAN AANDOLAN'}},
#  {'id': 'id-23',
#   'sparse_values': {'indices': [3204, 3540],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran kalash', 'original': 'KALASH JAGRAN'}},
#  {'id': 'id-24',
#   'sparse_values': {'indices': [3204, 7025],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran shramik', 'original': 'SHRAMIK JAGRAN'}},
#  {'id': 'id-25',
#   'sparse_values': {'indices': [3204, 3400],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'jagran jharkhand', 'original': 'JHARKHAND JAGRAN'}},
#  {'id': 'id-26',
#   'sparse_values': {'indices': [3204, 4370],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran mantra', 'original': 'JAGRAN MANTRA'}},
#  {'id': 'id-27',
#   'sparse_values': {'indices': [3204, 6478],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran samajwadi', 'original': 'SAMAJWADI JAGRAN'}},
#  {'id': 'id-28',
#   'sparse_values': {'indices': [3204, 8241],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran vyavsai', 'original': 'VYAVSAI JAGRAN'}},
#  {'id': 'id-29',
#   'sparse_values': {'indices': [4210], 'values': [1.0]},
#   'metadata': {'title': 'mahajagran', 'original': 'MAHAJAGRAN'}},
#  {'id': 'id-30',
#   'sparse_values': {'indices': [3204, 791],
#    'values': [0.5538707845730123, 0.8326026387157777]},
#   'metadata': {'title': 'bahujan jagran', 'original': 'BAHUJAN JAGRAN'}},
#  {'id': 'id-31',
#   'sparse_values': {'indices': [3204, 7687],
#    'values': [0.9647865760387496, 0.26303395730480517]},
#   'metadata': {'title': 'jagran times', 'original': 'JAGRAN TIMES'}},
#  {'id': 'id-32',
#   'sparse_values': {'indices': [3204, 3478],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'jagran junction', 'original': 'JAGRAN JUNCTION'}},
#  {'id': 'id-33',
#   'sparse_values': {'indices': [3204, 5743],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'jagran pravasi', 'original': 'PRAVASI JAGRAN'}},
#  {'id': 'id-34',
#   'sparse_values': {'indices': [3204, 6820],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran sewak', 'original': 'SEWAK JAGRAN'}},
#  {'id': 'id-35',
#   'sparse_values': {'indices': [3204, 4829],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran nandigiram', 'original': 'NANDIGIRAM JAGRAN'}},
#  {'id': 'id-36',
#   'sparse_values': {'indices': [3204, 5693],
#    'values': [0.5421402479683542, 0.840288017011317]},
#   'metadata': {'title': 'jagran prakhar', 'original': 'PRAKHAR JAGRAN'}},
#  {'id': 'id-37',
#   'sparse_values': {'indices': [3204, 5651, 8420],
#    'values': [0.4468260350171014, 0.6411543814373939, 0.6239130977904926]},
#   'metadata': {'title': 'jagran prabhat yug',
#    'original': 'YUG PRABHAT JAGRAN'}},
#  {'id': 'id-38',
#   'sparse_values': {'indices': [3204, 3268],
#    'values': [0.3878259949301174, 0.9217326063758755]},
#   'metadata': {'title': 'jagran jan jan', 'original': 'JAN JAN JAGRAN'}},
#  {'id': 'id-39',
#   'sparse_values': {'indices': [3204, 4008, 6231],
#    'values': [0.5317487339881466, 0.587230970379483, 0.6102483685592073]},
#   'metadata': {'title': 'jagran law review', 'original': 'JAGRAN LAW REVIEW'}},
#  {'id': 'id-40',
#   'sparse_values': {'indices': [3204, 5443],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'jagran patrakar', 'original': 'PATRAKAR JAGRAN'}},
#  {'id': 'id-41',
#   'sparse_values': {'indices': [3204, 4319],
#    'values': [0.5538707845730123, 0.8326026387157777]},
#   'metadata': {'title': 'jagran manav', 'original': 'MANAV JAGRAN'}},
#  {'id': 'id-42',
#   'sparse_values': {'indices': [3204, 3894],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran krisak', 'original': 'KRISAK JAGRAN'}},
#  {'id': 'id-43',
#   'sparse_values': {'indices': [3204, 3895, 6626],
#    'values': [0.41696742266352016, 0.6582214466356334, 0.6268035542546286]},
#   'metadata': {'title': 'jagran krishi saptahik',
#    'original': 'KRISHI JAGRAN SAPTAHIK'}},
#  {'id': 'id-44',
#   'sparse_values': {'indices': [3204, 8004],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran vande', 'original': 'VANDE JAGRAN'}},
#  {'id': 'id-45',
#   'sparse_values': {'indices': [3204, 3688],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran kaurav', 'original': 'KAURAV JAGRAN'}},
#  {'id': 'id-46',
#   'sparse_values': {'indices': [3204, 7020],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran shosit', 'original': 'SHOSIT JAGRAN'}},
#  {'id': 'id-47',
#   'sparse_values': {'indices': [3204, 821],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'balmik jagran', 'original': 'BALMIK JAGRAN'}},
#  {'id': 'id-48',
#   'sparse_values': {'indices': [3204, 5672],
#    'values': [0.6035747969196444, 0.7973063805861647]},
#   'metadata': {'title': 'jagran pradesh', 'original': 'PRADESH JAGRAN'}},
#  {'id': 'id-49',
#   'sparse_values': {'indices': [3204, 73],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'aatm jagran', 'original': 'AATM JAGRAN'}},
#  {'id': 'id-50',
#   'sparse_values': {'indices': [3204, 3777],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran khatik', 'original': 'KHATIK JAGRAN'}},
#  {'id': 'id-51',
#   'sparse_values': {'indices': [3204, 2610],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'goswami jagran', 'original': 'GOSWAMI JAGRAN'}},
#  {'id': 'id-52',
#   'sparse_values': {'indices': [3204, 5272],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'jagran pal', 'original': 'PAL JAGRAN'}},
#  {'id': 'id-53',
#   'sparse_values': {'indices': [3204, 4104],
#    'values': [0.6193893183458848, 0.7850839906143927]},
#   'metadata': {'title': 'jagran lok', 'original': 'LOK JAGRAN'}},
#  {'id': 'id-54',
#   'sparse_values': {'indices': [3204, 5693, 6098, 7979],
#    'values': [0.20290265597595933,
#     0.6289762513493391,
#     0.2883523960842132,
#     0.6928724869042842]},
#   'metadata': {'title': '- jagran prakhar prakhar rashtra vaishya vaishya',
#    'original': 'PRAKHAR VAISHYA - PRAKHAR RASHTRA VAISHYA JAGRAN'}},
#  {'id': 'id-55',
#   'sparse_values': {'indices': [3204, 3180],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'jabalpur jagran', 'original': 'JABALPUR JAGRAN'}},
#  {'id': 'id-56',
#   'sparse_values': {'indices': [3204, 3268, 6105],
#    'values': [0.5075064565278035, 0.6030865066332748, 0.615405445295592]},
#   'metadata': {'title': 'jagran jan rashtriya',
#    'original': 'RASHTRIYA JAN JAGRAN'}},
#  {'id': 'id-57',
#   'sparse_values': {'indices': [3204, 6107],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'jagran rastra', 'original': 'RASTRA JAGRAN'}},
#  {'id': 'id-58',
#   'sparse_values': {'indices': [3204, 8108],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran vidhhya', 'original': 'VIDHHYA JAGRAN'}},
#  {'id': 'id-59',
#   'sparse_values': {'indices': [3204, 415],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'anchalik jagran', 'original': 'ANCHALIK JAGRAN'}},
#  {'id': 'id-60',
#   'sparse_values': {'indices': [3204, 7046],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran shrutlekh', 'original': 'SHRUTLEKH JAGRAN'}},
#  {'id': 'id-61',
#   'sparse_values': {'indices': [3204, 8112],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran vidisha', 'original': 'VIDISHA JAGRAN'}},
#  {'id': 'id-62',
#   'sparse_values': {'indices': [3204, 6607],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran sanskruthika',
#    'original': 'SANSKRUTHIKA JAGRAN'}},
#  {'id': 'id-63',
#   'sparse_values': {'indices': [3204, 26],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'aagaj jagran', 'original': 'AAGAJ JAGRAN'}},
#  {'id': 'id-64',
#   'sparse_values': {'indices': [3204, 169],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'adhyapak jagran', 'original': 'ADHYAPAK JAGRAN'}},
#  {'id': 'id-65',
#   'sparse_values': {'indices': [3204, 5871],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'jagran punjabi', 'original': 'PUNJABI JAGRAN'}},
#  {'id': 'id-66',
#   'sparse_values': {'indices': [3204, 8414],
#    'values': [0.5754706566186509, 0.8178224277744519]},
#   'metadata': {'title': 'jagran youth', 'original': 'YOUTH JAGRAN'}},
#  {'id': 'id-67',
#   'sparse_values': {'indices': [3204, 280],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'ajmer jagran', 'original': 'AJMER JAGRAN'}},
#  {'id': 'id-68',
#   'sparse_values': {'indices': [3204], 'values': [1.0]},
#   'metadata': {'title': 'jagran', 'original': 'JAGRAN'}},
#  {'id': 'id-69',
#   'sparse_values': {'indices': [3204, 985, 2710, 8174],
#    'values': [0.3596453288052113,
#     0.41384283979326475,
#     0.6140588751147261,
#     0.5677332466161151]},
#   'metadata': {'title': 'bharat hadoti jagran vir',
#    'original': 'VIR BHARAT HADOTI JAGRAN'}},
#  {'id': 'id-70',
#   'sparse_values': {'indices': [360, 6523],
#    'values': [0.7598754291445414, 0.6500687134314335]},
#   'metadata': {'title': 'amarjagran samrat', 'original': 'AMARJAGRAN SAMRAT'}},
#  {'id': 'id-71',
#   'sparse_values': {'indices': [165, 5872],
#    'values': [0.7071067811865476, 0.7071067811865476]},
#   'metadata': {'title': 'adhimaik punjagran',
#    'original': 'ADHIMAIK PUNJAGRAN'}},
#  {'id': 'id-72',
#   'sparse_values': {'indices': [3204, 1292],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'chaitanya jagran', 'original': 'CHAITANYA JAGRAN'}},
#  {'id': 'id-73',
#   'sparse_values': {'indices': [3204, 4411],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran maruthar', 'original': 'MARUTHAR JAGRAN'}},
#  {'id': 'id-74',
#   'sparse_values': {'indices': [3204, 1162],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'brahman jagran', 'original': 'BRAHMAN JAGRAN'}},
#  {'id': 'id-75',
#   'sparse_values': {'indices': [5864, 6552],
#    'values': [0.7766051356607929, 0.6299876691374852]},
#   'metadata': {'title': 'punarjagran sandesh',
#    'original': 'PUNARJAGRAN SANDESH'}},
#  {'id': 'id-76',
#   'sparse_values': {'indices': [3204, 101, 3226],
#    'values': [0.41706196398306156, 0.6725012704849528, 0.611392966425617]},
#   'metadata': {'title': 'abhiyan jagran jain',
#    'original': 'JAIN JAGRAN ABHIYAN'}},
#  {'id': 'id-77',
#   'sparse_values': {'indices': [3204, 6426],
#    'values': [0.582250577267142, 0.813009388182006]},
#   'metadata': {'title': 'jagran sai', 'original': 'SAI JAGRAN'}},
#  {'id': 'id-78',
#   'sparse_values': {'indices': [3204, 679],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'audichya jagran', 'original': 'AUDICHYA JAGRAN'}},
#  {'id': 'id-79',
#   'sparse_values': {'indices': [3204, 3268, 6749, 8407],
#    'values': [0.37069928704146365,
#     0.4405140765357614,
#     0.517615632038797,
#     0.6329324169529259]},
#   'metadata': {'title': 'jagran jan sciences yogic',
#    'original': 'JAN JAGRAN YOGIC SCIENCES'}},
#  {'id': 'id-80',
#   'sparse_values': {'indices': [3204, 3226, 3233],
#    'values': [0.3975518421175759, 0.5827920574174078, 0.708735458856199]},
#   'metadata': {'title': 'jagran jain jaiswal',
#    'original': 'JAISWAL JAIN JAGRAN'}},
#  {'id': 'id-81',
#   'sparse_values': {'indices': [3204, 3494],
#    'values': [0.5677905871312545, 0.8231730371951849]},
#   'metadata': {'title': 'jagran jyoti', 'original': 'JYOTI JAGRAN'}},
#  {'id': 'id-82',
#   'sparse_values': {'indices': [3204, 1780],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'deepotsav jagran', 'original': 'DEEPOTSAV JAGRAN'}},
#  {'id': 'id-83',
#   'sparse_values': {'indices': [3204, 106],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'abhyudaya jagran', 'original': 'ABHYUDAYA JAGRAN'}},
#  {'id': 'id-84',
#   'sparse_values': {'indices': [3204, 7423],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran swadeep', 'original': 'SWADEEP JAGRAN'}},
#  {'id': 'id-85',
#   'sparse_values': {'indices': [3204, 605],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'aryavart jagran', 'original': 'ARYAVART JAGRAN'}},
#  {'id': 'id-86',
#   'sparse_values': {'indices': [3204, 4935],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran navswar', 'original': 'NAVSWAR JAGRAN'}},
#  {'id': 'id-87',
#   'sparse_values': {'indices': [3204, 3979],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'jagran lakshya', 'original': 'LAKSHYA JAGRAN'}},
#  {'id': 'id-88',
#   'sparse_values': {'indices': [3204, 3333, 6867],
#    'values': [0.44533316543014284, 0.6390122504925029, 0.6271696066364153]},
#   'metadata': {'title': 'jagran janta shakti',
#    'original': 'JANTA JAGRAN SHAKTI'}},
#  {'id': 'id-89',
#   'sparse_values': {'indices': [3204, 3268, 6867],
#    'values': [0.4769759622341176, 0.5668061225858702, 0.6717326483430809]},
#   'metadata': {'title': 'jagran jan shakti', 'original': 'JAN SHAKTI JAGRAN'}},
#  {'id': 'id-90',
#   'sparse_values': {'indices': [3204, 4095],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran lodhi', 'original': 'LODHI JAGRAN'}},
#  {'id': 'id-91',
#   'sparse_values': {'indices': [3204, 3893],
#    'values': [0.5538707845730123, 0.8326026387157777]},
#   'metadata': {'title': 'jagran kranti', 'original': 'KRANTI JAGRAN'}},
#  {'id': 'id-92',
#   'sparse_values': {'indices': [3204, 3952],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran kutumb', 'original': 'KUTUMB JAGRAN'}},
#  {'id': 'id-93',
#   'sparse_values': {'indices': [3204, 7451],
#    'values': [0.5538707845730123, 0.8326026387157777]},
#   'metadata': {'title': 'jagran swatantra', 'original': 'SWATANTRA JAGRAN'}},
#  {'id': 'id-94',
#   'sparse_values': {'indices': [3204, 3246],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran jalaun', 'original': 'JALAUN JAGRAN'}},
#  {'id': 'id-95',
#   'sparse_values': {'indices': [3204, 4656, 6463],
#    'values': [0.46104753898766065, 0.6840396681487958, 0.5652653352119752]},
#   'metadata': {'title': 'jagran morning samachar',
#    'original': 'MORNING JAGRAN SAMACHAR'}},
#  {'id': 'id-96',
#   'sparse_values': {'indices': [3204, 7397],
#    'values': [0.5421402479683542, 0.840288017011317]},
#   'metadata': {'title': 'jagran surya', 'original': 'SURYA JAGRAN'}},
#  {'id': 'id-97',
#   'sparse_values': {'indices': [3204, 3360],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran jaunpur', 'original': 'JAUNPUR JAGRAN'}},
#  {'id': 'id-98',
#   'sparse_values': {'indices': [3204, 3213, 5965],
#    'values': [0.3686952329830815, 0.6572913452859209, 0.6572913452859209]},
#   'metadata': {'title': 'jagran jagta rahega',
#    'original': 'JAGTA RAHEGA JAGRAN'}},
#  {'id': 'id-99',
#   'sparse_values': {'indices': [3204, 3772],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran khas', 'original': 'KHAS JAGRAN'}},
#  {'id': 'id-100',
#   'sparse_values': {'indices': [3204, 4355],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran manohar', 'original': 'MANOHAR JAGRAN'}},
#  {'id': 'id-101',
#   'sparse_values': {'indices': [3204, 418, 3456, 4310, 5149, 7570],
#    'values': [0.3854185965859975,
#     0.366423447194639,
#     0.29501272682251295,
#     0.5297325249441713,
#     0.24476915416487185,
#     0.5381685302487588]},
#   'metadata': {'title': 'and jagran journal management of technology',
#    'original': 'JAGRAN JOURNAL OF MANAGEMENT AND TECHNOLOGY'}},
#  {'id': 'id-102',
#   'sparse_values': {'indices': [3204, 3445],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'jagran josh', 'original': 'JAGRAN JOSH'}},
#  {'id': 'id-103',
#   'sparse_values': {'indices': [3204, 3748, 3786],
#    'values': [0.37546745026626466, 0.6693645141539227, 0.6410735846859025]},
#   'metadata': {'title': 'jagran khalihan khet',
#    'original': 'JAGRAN KHET KHALIHAN'}},
#  {'id': 'id-104',
#   'sparse_values': {'indices': [3204, 7687, 1698],
#    'values': [0.5123256778426195, 0.13967757617970683, 0.8473562264689288]},
#   'metadata': {'title': 'dalit jagran times',
#    'original': 'DALIT JAGRAN TIMES'}},
#  {'id': 'id-105',
#   'sparse_values': {'indices': [3204, 7365],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'jagran suprabhat', 'original': 'SUPRABHAT JAGRAN'}},
#  {'id': 'id-106',
#   'sparse_values': {'indices': [3204, 6553],
#    'values': [0.5635241674927545, 0.8260995779272605]},
#   'metadata': {'title': 'jagran sandhya', 'original': 'SANDHYA JAGRAN'}},
#  {'id': 'id-107',
#   'sparse_values': {'indices': [3204, 7436],
#    'values': [0.5351380348041863, 0.8447646321348411]},
#   'metadata': {'title': 'jagran swaraj', 'original': 'SWARAJ JAGRAN'}},
#  {'id': 'id-108',
#   'sparse_values': {'indices': [3204, 8163],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran vindhyavashini',
#    'original': 'VINDHYAVASHINI JAGRAN'}},
#  {'id': 'id-109',
#   'sparse_values': {'indices': [3204, 8047],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran vasundhara', 'original': 'VASUNDHARA JAGRAN'}},
#  {'id': 'id-110',
#   'sparse_values': {'indices': [3204, 2700],
#    'values': [0.5421402479683542, 0.840288017011317]},
#   'metadata': {'title': 'gyan jagran', 'original': 'GYAN JAGRAN'}},
#  {'id': 'id-111',
#   'sparse_values': {'indices': [3204, 3296, 4148],
#    'values': [0.4231151799926314, 0.6453062348084794, 0.6360451302990273]},
#   'metadata': {'title': 'jagran janhit lucknow',
#    'original': 'LUCKNOW JANHIT JAGRAN'}},
#  {'id': 'id-112',
#   'sparse_values': {'indices': [3204, 4653],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'jagran morcha', 'original': 'JAGRAN MORCHA'}},
#  {'id': 'id-113',
#   'sparse_values': {'indices': [3204, 7421],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'jagran swabhiman', 'original': 'SWABHIMAN JAGRAN'}},
#  {'id': 'id-114',
#   'sparse_values': {'indices': [6105, 5864, 5048],
#    'values': [0.45440660389208304, 0.6398239021730145, 0.6197902972355732]},
#   'metadata': {'title': 'nirbhik punarjagran rashtriya',
#    'original': 'NIRBHIK RASHTRIYA PUNARJAGRAN'}},
#  {'id': 'id-115',
#   'sparse_values': {'indices': [3204, 6636],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'jagran saransh', 'original': 'SARANSH JAGRAN'}},
#  {'id': 'id-116',
#   'sparse_values': {'indices': [3204, 715],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'awadh jagran', 'original': 'AWADH JAGRAN'}},
#  {'id': 'id-117',
#   'sparse_values': {'indices': [3204, 7687, 8420],
#    'values': [0.5750503462956746, 0.15677847514907256, 0.8029555460641371]},
#   'metadata': {'title': 'jagran times yug', 'original': 'YUG JAGRAN TIMES'}},
#  {'id': 'id-118',
#   'sparse_values': {'indices': [3204, 5272, 3902],
#    'values': [0.3972889493656095, 0.6406178128697815, 0.6570923135647745]},
#   'metadata': {'title': 'jagran kshatriya pal',
#    'original': 'PAL KSHATRIYA JAGRAN'}},
#  {'id': 'id-119',
#   'sparse_values': {'indices': [3204, 5798],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran prod', 'original': 'PROD JAGRAN'}},
#  {'id': 'id-120',
#   'sparse_values': {'indices': [3204, 7853],
#    'values': [0.5421402479683542, 0.840288017011317]},
#   'metadata': {'title': 'jagran udyog', 'original': 'UDYOG JAGRAN'}},
#  {'id': 'id-121',
#   'sparse_values': {'indices': [3204, 7687, 7249],
#    'values': [0.5123256778426195, 0.13967757617970683, 0.8473562264689288]},
#   'metadata': {'title': 'jagran srishti times',
#    'original': 'SRISHTI JAGRAN TIMES'}},
#  {'id': 'id-122',
#   'sparse_values': {'indices': [3204, 3333, 3320],
#    'values': [0.40912952455856705, 0.5870633461098198, 0.6985482515823963]},
#   'metadata': {'title': 'jagran jansabha janta',
#    'original': 'JANTA JAGRAN JANSABHA'}},
#  {'id': 'id-123',
#   'sparse_values': {'indices': [3204, 4247],
#    'values': [0.5483239297621362, 0.8362660270812201]},
#   'metadata': {'title': 'jagran mahila', 'original': 'MAHILA JAGRAN'}},
#  {'id': 'id-124',
#   'sparse_values': {'indices': [3204, 2541],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'ginvani jagran', 'original': 'GINVANI JAGRAN'}},
#  {'id': 'id-125',
#   'sparse_values': {'indices': [3204, 7687, 6406],
#    'values': [0.5525293179461298, 0.15063846931101812, 0.8197678966473487]},
#   'metadata': {'title': 'jagran sahara times',
#    'original': 'SAHARA JAGRAN TIMES'}},
#  {'id': 'id-126',
#   'sparse_values': {'indices': [3204, 7249],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'jagran srishti', 'original': 'SRISHTI JAGRAN'}},
#  {'id': 'id-127',
#   'sparse_values': {'indices': [3204, 1854, 7035],
#    'values': [0.41467962685375087, 0.7392700133171316, 0.5305852000221283]},
#   'metadata': {'title': 'devvansh jagran shri',
#    'original': 'SHRI DEVVANSH JAGRAN'}},
#  {'id': 'id-128',
#   'sparse_values': {'indices': [3204, 6067],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran rampur', 'original': 'RAMPUR JAGRAN'}},
#  {'id': 'id-129',
#   'sparse_values': {'indices': [3204, 7970],
#    'values': [0.505384564220115, 0.8628942242523382]},
#   'metadata': {'title': 'jagran vaidik', 'original': 'VAIDIK JAGRAN'}},
#  {'id': 'id-130',
#   'sparse_values': {'indices': [3204, 1785, 2452, 3727],
#    'values': [0.34065748924104194,
#     0.5816390145749895,
#     0.5493010969567083,
#     0.493879374574786]},
#   'metadata': {'title': 'dehat gaon jagran khabar',
#    'original': 'JAGRAN GAON DEHAT KHABAR'}},
#  {'id': 'id-131',
#   'sparse_values': {'indices': [3204, 4850],
#    'values': [0.5483239297621362, 0.8362660270812201]},
#   'metadata': {'title': 'jagran nari', 'original': 'NARI JAGRAN'}},
#  {'id': 'id-132',
#   'sparse_values': {'indices': [3204, 3268, 989, 3631, 5427],
#    'values': [0.31820661288584484,
#     0.37813531647634807,
#     0.48530688796393434,
#     0.5262948284533129,
#     0.493203012954209]},
#   'metadata': {'title': 'bharatiya jagran jan karm path',
#    'original': 'BHARATIYA JAN JAGRAN KARM PATH'}},
#  {'id': 'id-133',
#   'sparse_values': {'indices': [3204, 1838],
#    'values': [0.5173977077410418, 0.8557450625182219]},
#   'metadata': {'title': 'devbhoomi jagran', 'original': 'DEVBHOOMI JAGRAN'}},
#  {'id': 'id-134',
#   'sparse_values': {'indices': [3204, 2864],
#    'values': [0.5270411483855029, 0.8498397660197423]},
#   'metadata': {'title': 'himalaya jagran', 'original': 'HIMALAYA JAGRAN'}},
#  {'id': 'id-135',
#   'sparse_values': {'indices': [6463, 3298],
#    'values': [0.5832755748652795, 0.8122743402112229]},
#   'metadata': {'title': 'janjagran samachar',
#    'original': 'JANJAGRAN SAMACHAR'}},
#  {'id': 'id-136',
#   'sparse_values': {'indices': [7947, 3298],
#    'values': [0.686607254602951, 0.7270285262124165]},
#   'metadata': {'title': 'janjagran uttrakhand',
#    'original': 'UTTRAKHAND JANJAGRAN'}},
#  {'id': 'id-137',
#   'sparse_values': {'indices': [3204, 3494],
#    'values': [0.5677905871312545, 0.8231730371951849]},
#   'metadata': {'title': 'jagran jyoti', 'original': 'JAGRAN JYOTI'}},
#  {'id': 'id-138',
#   'sparse_values': {'indices': [3204, 3268, 1408],
#    'values': [0.4515656544677879, 0.5366102235068353, 0.7128379393193255]},
#   'metadata': {'title': 'chetna jagran jan', 'original': 'JAN CHETNA JAGRAN'}},
#  {'id': 'id-139',
#   'sparse_values': {'indices': [3204, 6687],
#    'values': [0.4892215228632858, 0.8721595619881304]},
#   'metadata': {'title': 'jagran satat', 'original': 'SATAT JAGRAN'}},
#  {'id': 'id-140',
#   'sparse_values': {'indices': [3204, 3226],
#    'values': [0.5635241674927545, 0.8260995779272605]},
#   'metadata': {'title': 'jagran jain', 'original': 'JAIN JAGRAN'}},
#  {'id': 'id-141',
#   'sparse_values': {'indices': [7687, 479],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'anuja times', 'original': 'ANUJA TIMES'}},
#  {'id': 'id-142',
#   'sparse_values': {'indices': [7687, 6463, 2414, 4959],
#    'values': [0.10315897656030681,
#     0.4639093258830358,
#     0.6460439247546264,
#     0.5973052906189732]},
#   'metadata': {'title': 'gagan neel samachar times',
#    'original': 'NEEL GAGAN SAMACHAR TIMES'}},
#  {'id': 'id-143',
#   'sparse_values': {'indices': [7687, 6406, 50, 3500, 7292],
#    'values': [0.08944612526283215,
#     0.48676186305753966,
#     0.4931854896576365,
#     0.466247802397724,
#     0.5426263345053104]},
#   'metadata': {'title': 'aap ka sahara sub times',
#    'original': 'AAP SUB KA SAHARA TIMES'}},
#  {'id': 'id-144',
#   'sparse_values': {'indices': [7687, 7711],
#    'values': [0.21935747053714633, 0.9756445562393843]},
#   'metadata': {'title': 'times today', 'original': 'TODAY TIMES'}},
#  {'id': 'id-145',
#   'sparse_values': {'indices': [7687, 3826, 7637],
#    'values': [0.15343288821973972, 0.9074661175756785, 0.39110560500288627]},
#   'metadata': {'title': 'king the times', 'original': 'THE KING TIMES'}},
#  {'id': 'id-146',
#   'sparse_values': {'indices': [7687, 2140],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'emerald times', 'original': 'EMERALD TIMES'}},
#  {'id': 'id-147',
#   'sparse_values': {'indices': [7687, 7637, 1129, 5624],
#    'values': [0.10368735468429773,
#     0.26430256286952863,
#     0.6780092505781804,
#     0.6780092505781804]},
#   'metadata': {'title': 'blair port the times',
#    'original': 'THE PORT BLAIR TIMES'}},
#  {'id': 'id-148',
#   'sparse_values': {'indices': [7687, 7637, 1751],
#    'values': [0.15024402839621498, 0.38297709380154016, 0.9114577760678788]},
#   'metadata': {'title': 'dawn the times', 'original': 'THE DAWN TIMES'}},
#  {'id': 'id-149',
#   'sparse_values': {'indices': [7687, 5149, 7637, 419],
#    'values': [0.13401179850160336,
#     0.3121666402654175,
#     0.34160059253679204,
#     0.8763000979951331]},
#   'metadata': {'title': 'andaman of the times',
#    'original': 'THE TIMES OF ANDAMAN'}},
#  {'id': 'id-150',
#   'sparse_values': {'indices': [7687, 3160, 4996],
#    'values': [0.1321762815059711, 0.8277678444557839, 0.5452795854351044]},
#   'metadata': {'title': 'island new times', 'original': 'NEW ISLAND TIMES'}},
#  {'id': 'id-151',
#   'sparse_values': {'indices': [7687, 6894],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'shanthi times', 'original': 'SHANTHI TIMES'}},
#  {'id': 'id-152',
#   'sparse_values': {'indices': [7687, 405],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'ananta times', 'original': 'ANANTA TIMES'}},
#  {'id': 'id-153',
#   'sparse_values': {'indices': [7687, 304],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'akshra times', 'original': 'AKSHRA TIMES'}},
#  {'id': 'id-154',
#   'sparse_values': {'indices': [7687, 3514],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'kadiri times', 'original': 'KADIRI TIMES'}},
#  {'id': 'id-155',
#   'sparse_values': {'indices': [7687, 961],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'bhagavan times', 'original': 'BHAGAVAN TIMES'}},
#  {'id': 'id-156',
#   'sparse_values': {'indices': [7687, 6883],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'shambu times', 'original': 'SHAMBU TIMES'}},
#  {'id': 'id-157',
#   'sparse_values': {'indices': [7687, 5484],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'penna times', 'original': 'PENNA TIMES'}},
#  {'id': 'id-158',
#   'sparse_values': {'indices': [7687, 7996],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'times vamsi', 'original': 'VAMSI TIMES'}},
#  {'id': 'id-159',
#   'sparse_values': {'indices': [7687, 5455],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'pavitra times', 'original': 'PAVITRA TIMES'}},
#  {'id': 'id-160',
#   'sparse_values': {'indices': [7687, 4833],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'nandu times', 'original': 'NANDU TIMES'}},
#  {'id': 'id-161',
#   'sparse_values': {'indices': [7687, 5149, 7637, 173],
#    'values': [0.1384835900201002,
#     0.32258321664081663,
#     0.3529993398821703,
#     0.8672680264367877]},
#   'metadata': {'title': 'adithya of the times',
#    'original': 'THE TIMES OF ADITHYA'}},
#  {'id': 'id-162',
#   'sparse_values': {'indices': [7687, 3735],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'khadri times', 'original': 'KHADRI TIMES'}},
#  {'id': 'id-163',
#   'sparse_values': {'indices': [7687, 4996, 4304],
#    'values': [0.12827143111851302, 0.5291705288313062, 0.8387639664263149]},
#   'metadata': {'title': 'mamatha new times', 'original': 'NEW MAMATHA TIMES'}},
#  {'id': 'id-164',
#   'sparse_values': {'indices': [7687, 7470],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'tadipatri times', 'original': 'TADIPATRI TIMES'}},
#  {'id': 'id-165',
#   'sparse_values': {'indices': [7687, 6876],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'shalini times', 'original': 'SHALINI TIMES'}},
#  {'id': 'id-166',
#   'sparse_values': {'indices': [7687, 5291],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'pamidi times', 'original': 'PAMIDI TIMES'}},
#  {'id': 'id-167',
#   'sparse_values': {'indices': [7687, 2780],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'harika times', 'original': 'HARIKA TIMES'}},
#  {'id': 'id-168',
#   'sparse_values': {'indices': [7687, 3710],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'keerthi times', 'original': 'KEERTHI TIMES'}},
#  {'id': 'id-169',
#   'sparse_values': {'indices': [7687, 2760, 3034],
#    'values': [0.16496324066108317, 0.9378278662413275, 0.3053948633029579]},
#   'metadata': {'title': 'happy india times', 'original': 'HAPPY INDIA TIMES'}},
#  {'id': 'id-170',
#   'sparse_values': {'indices': [7687, 5901],
#    'values': [0.16264438796429254, 0.9866847536390337]},
#   'metadata': {'title': 'pyramid times', 'original': 'PYRAMID TIMES'}},
#  {'id': 'id-171',
#   'sparse_values': {'indices': [7687, 2760, 7703],
#    'values': [0.11941828304146494, 0.6789015123985781, 0.7244529040167842]},
#   'metadata': {'title': 'happy times tirupati',
#    'original': 'TIRUPATI HAPPY TIMES'}},
#  {'id': 'id-172',
#   'sparse_values': {'indices': [7687, 2186],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'eswar times', 'original': 'ESWAR TIMES'}},
#  {'id': 'id-173',
#   'sparse_values': {'indices': [7687, 6184],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'registration times',
#    'original': 'REGISTRATION TIMES'}},
#  {'id': 'id-174',
#   'sparse_values': {'indices': [7687, 5149, 7703],
#    'values': [0.15209463540075716, 0.354288740740092, 0.9226845127491361]},
#   'metadata': {'title': 'of times tirupati', 'original': 'TIMES OF TIRUPATI'}},
#  {'id': 'id-175',
#   'sparse_values': {'indices': [7687, 418, 2169, 5602],
#    'values': [0.10789164911400434,
#     0.37623383976628705,
#     0.6247081444407941,
#     0.6756827836607326]},
#   'metadata': {'title': 'and environment pollution times',
#    'original': 'ENVIRONMENT AND POLLUTION TIMES'}},
#  {'id': 'id-176',
#   'sparse_values': {'indices': [7687, 7733],
#    'values': [0.17323962484789424, 0.984879704523634]},
#   'metadata': {'title': 'times tourism', 'original': 'TOURISM TIMES'}},
#  {'id': 'id-177',
#   'sparse_values': {'indices': [7687, 3457],
#    'values': [0.18073143462295554, 0.9835324847401474]},
#   'metadata': {'title': 'journalist times', 'original': 'JOURNALIST TIMES'}},
#  {'id': 'id-178',
#   'sparse_values': {'indices': [7687, 5993],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'rajamahendravaram times',
#    'original': 'RAJAMAHENDRAVARAM TIMES'}},
#  {'id': 'id-179',
#   'sparse_values': {'indices': [7687, 422, 6479],
#    'values': [0.11543030026763307, 0.6457233825321229, 0.7547961042767759]},
#   'metadata': {'title': 'andhra samakaleena times',
#    'original': 'SAMAKALEENA ANDHRA TIMES'}},
#  {'id': 'id-180',
#   'sparse_values': {'indices': [7687, 3530],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'kakinada times', 'original': 'KAKINADA TIMES'}},
#  {'id': 'id-181',
#   'sparse_values': {'indices': [7687, 2568],
#    'values': [0.15768042072751778, 0.987490194847115]},
#   'metadata': {'title': 'godavari times', 'original': 'GODAVARI TIMES'}},
#  {'id': 'id-182',
#   'sparse_values': {'indices': [7687, 1935],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'dikhsutchi times', 'original': 'DIKHSUTCHI TIMES'}},
#  {'id': 'id-183',
#   'sparse_values': {'indices': [7687, 1502],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'coasta times', 'original': 'COASTA TIMES'}},
#  {'id': 'id-184',
#   'sparse_values': {'indices': [7687, 1477, 7637, 3020],
#    'values': [0.14500581074464766,
#     0.6909436731245535,
#     0.3696247004032031,
#     0.6041090433616104]},
#   'metadata': {'title': 'city in the times', 'original': 'TIMES IN THE CITY'}},
#  {'id': 'id-185',
#   'sparse_values': {'indices': [7687, 4813],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'namburi times', 'original': 'NAMBURI TIMES'}},
#  {'id': 'id-186',
#   'sparse_values': {'indices': [7687, 2687],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'guntur times', 'original': 'GUNTUR TIMES'}},
#  {'id': 'id-187',
#   'sparse_values': {'indices': [7687, 5609],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'ponnur times', 'original': 'PONNUR TIMES'}},
#  {'id': 'id-188',
#   'sparse_values': {'indices': [7687, 850],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'bapatla times', 'original': 'BAPATLA TIMES'}},
#  {'id': 'id-189',
#   'sparse_values': {'indices': [7687, 4828],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'nandi times', 'original': 'NANDI TIMES'}},
#  {'id': 'id-190',
#   'sparse_values': {'indices': [7687, 7324],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'sujana times', 'original': 'SUJANA TIMES'}},
#  {'id': 'id-191',
#   'sparse_values': {'indices': [7687, 7444],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'swarnapuri times', 'original': 'SWARNAPURI TIMES'}},
#  {'id': 'id-192',
#   'sparse_values': {'indices': [7687, 1538],
#    'values': [0.17845289196765482, 0.9839484566522682]},
#   'metadata': {'title': 'commerce times', 'original': 'COMMERCE TIMES'}},
#  {'id': 'id-193',
#   'sparse_values': {'indices': [7687, 4008],
#    'values': [0.23967962961475275, 0.9708520356613232]},
#   'metadata': {'title': 'law times', 'original': 'LAW TIMES'}},
#  {'id': 'id-194',
#   'sparse_values': {'indices': [7687, 8287],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'times weavers', 'original': 'WEAVERS TIMES'}},
#  {'id': 'id-195',
#   'sparse_values': {'indices': [7687, 7637, 7603],
#    'values': [0.14106098818864146, 0.35956921470976927, 0.9223945887982236]},
#   'metadata': {'title': 'tenali the times', 'original': 'THE TENALI TIMES'}},
#  {'id': 'id-196',
#   'sparse_values': {'indices': [7687, 8135],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'times vijayawada', 'original': 'VIJAYAWADA TIMES'}},
#  {'id': 'id-197',
#   'sparse_values': {'indices': [7687, 2640],
#    'values': [0.17323962484789424, 0.984879704523634]},
#   'metadata': {'title': 'green times', 'original': 'GREEN TIMES'}},
#  {'id': 'id-198',
#   'sparse_values': {'indices': [7687, 605],
#    'values': [0.15768042072751778, 0.987490194847115]},
#   'metadata': {'title': 'aryavart times', 'original': 'ARYAVART TIMES'}},
#  {'id': 'id-199',
#   'sparse_values': {'indices': [7687, 5149, 7637, 3034],
#    'values': [0.24730258989294718,
#     0.5760658350905878,
#     0.6303826393487534,
#     0.45782890983567653]},
#   'metadata': {'title': 'india of the times',
#    'original': 'THE TIMES OF INDIA'}},
#  {'id': 'id-200',
#   'sparse_values': {'indices': [7687, 5149, 7951],
#    'values': [0.1425892219593549, 0.33214686210318384, 0.9323876746161086]},
#   'metadata': {'title': 'of times vaartha', 'original': 'TIMES OF VAARTHA'}},
#  {'id': 'id-201',
#   'sparse_values': {'indices': [7687, 6273],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'riyaz times', 'original': 'RIYAZ TIMES'}},
#  {'id': 'id-202',
#   'sparse_values': {'indices': [7687, 973, 1819],
#    'values': [0.1191477298459962, 0.7791042916172408, 0.6154675631226578]},
#   'metadata': {'title': 'bhakt desh times', 'original': 'DESH BHAKT TIMES'}},
#  {'id': 'id-203',
#   'sparse_values': {'indices': [7687, 7260],
#    'values': [0.19727329338286348, 0.9803485337969751]},
#   'metadata': {'title': 'state times', 'original': 'STATE TIMES'}},
#  {'id': 'id-204',
#   'sparse_values': {'indices': [7687, 1360],
#    'values': [0.15768042072751778, 0.987490194847115]},
#   'metadata': {'title': 'charminar times', 'original': 'CHARMINAR TIMES'}},
#  {'id': 'id-205',
#   'sparse_values': {'indices': [7687, 1065],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'bhupathi times', 'original': 'BHUPATHI TIMES'}},
#  {'id': 'id-206',
#   'sparse_values': {'indices': [7687, 5678],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'pragathi times', 'original': 'PRAGATHI TIMES'}},
#  {'id': 'id-207',
#   'sparse_values': {'indices': [7687, 4863],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'naser times', 'original': 'NASER TIMES'}},
#  {'id': 'id-208',
#   'sparse_values': {'indices': [7687, 154],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'adam times', 'original': 'ADAM TIMES'}},
#  {'id': 'id-209',
#   'sparse_values': {'indices': [7687, 6250],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'rida times', 'original': 'RIDA TIMES'}},
#  {'id': 'id-210',
#   'sparse_values': {'indices': [7687, 6875],
#    'values': [0.15768042072751778, 0.987490194847115]},
#   'metadata': {'title': 'shalimar times', 'original': 'SHALIMAR TIMES'}},
#  {'id': 'id-211',
#   'sparse_values': {'indices': [7687, 6600],
#    'values': [0.16671221505815761, 0.986005597017787]},
#   'metadata': {'title': 'sansani times', 'original': 'SANSANI TIMES'}},
#  {'id': 'id-212',
#   'sparse_values': {'indices': [7687, 4104, 6703],
#    'values': [0.13619899847963482, 0.6332070726942621, 0.7619046107637804]},
#   'metadata': {'title': 'lok satta times', 'original': 'LOK SATTA TIMES'}},
#  {'id': 'id-213',
#   'sparse_values': {'indices': [7687, 4506],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'mehar times', 'original': 'MEHAR TIMES'}},
#  {'id': 'id-214',
#   'sparse_values': {'indices': [7687, 7250],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'sriven times', 'original': 'SRIVEN TIMES'}},
#  {'id': 'id-215',
#   'sparse_values': {'indices': [7687, 8397],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'times yerukala', 'original': 'YERUKALA TIMES'}},
#  {'id': 'id-216',
#   'sparse_values': {'indices': [7687, 5127, 5333],
#    'values': [0.1173063888609598, 0.6307553649485161, 0.7670638048565879]},
#   'metadata': {'title': '& nursing paramedical times',
#    'original': 'PARAMEDICAL & NURSING TIMES'}},
#  {'id': 'id-217',
#   'sparse_values': {'indices': [7687, 7541],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'tarnaka times', 'original': 'TARNAKA TIMES'}},
#  {'id': 'id-218',
#   'sparse_values': {'indices': [7687, 2029],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'dravidian times', 'original': 'DRAVIDIAN TIMES'}},
#  {'id': 'id-219',
#   'sparse_values': {'indices': [7687, 7764],
#    'values': [0.17845289196765482, 0.9839484566522682]},
#   'metadata': {'title': 'times transport', 'original': 'TRANSPORT TIMES'}},
#  {'id': 'id-220',
#   'sparse_values': {'indices': [7687, 4008, 422, 4040, 7363],
#    'values': [0.08893209510142606,
#     0.36023046974673517,
#     0.49749098054337765,
#     0.5815249442485452,
#     0.5259815154752422]},
#   'metadata': {'title': '(legislative andhra law supplement) times',
#    'original': 'ANDHRA LAW TIMES (LEGISLATIVE SUPPLEMENT)'}},
#  {'id': 'id-221',
#   'sparse_values': {'indices': [7687, 4310, 5149, 1971],
#    'values': [0.11577989490983431,
#     0.5836823454359343,
#     0.26969730432991446,
#     0.7570820956793602]},
#   'metadata': {'title': 'disaster management of times',
#    'original': 'TIMES OF DISASTER MANAGEMENT'}},
#  {'id': 'id-222',
#   'sparse_values': {'indices': [7687, 2189, 4061],
#    'values': [0.12301662406794164, 0.746282296802214, 0.6541633157572647]},
#   'metadata': {'title': 'eternal life times',
#    'original': 'ETERNAL LIFE TIMES'}},
#  {'id': 'id-223',
#   'sparse_values': {'indices': [7687, 161],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'adeeb times', 'original': 'ADEEB TIMES'}},
#  {'id': 'id-224',
#   'sparse_values': {'indices': [7687, 7637, 2090, 8284],
#    'values': [0.11935761432440055,
#     0.304246583008923,
#     0.5783139995095279,
#     0.7474895949787368]},
#   'metadata': {'title': 'economic the times wealth',
#    'original': 'THE ECONOMIC TIMES WEALTH'}},
#  {'id': 'id-225',
#   'sparse_values': {'indices': [7687, 3034, 2673],
#    'values': [0.15136320816576548, 0.28021725374473855, 0.9479279877277197]},
#   'metadata': {'title': 'gulf india times', 'original': 'INDIA GULF TIMES'}},
#  {'id': 'id-226',
#   'sparse_values': {'indices': [7687, 6832],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'shadan times', 'original': 'SHADAN TIMES'}},
#  {'id': 'id-227',
#   'sparse_values': {'indices': [7687, 3489],
#    'values': [0.16671221505815761, 0.986005597017787]},
#   'metadata': {'title': 'justice times', 'original': 'JUSTICE TIMES'}},
#  {'id': 'id-228',
#   'sparse_values': {'indices': [7687, 3487],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'jurrat times', 'original': 'JURRAT TIMES'}},
#  {'id': 'id-229',
#   'sparse_values': {'indices': [7687, 2104],
#    'values': [0.2120858475499415, 0.9772510390217158]},
#   'metadata': {'title': 'education times', 'original': 'EDUCATION TIMES'}},
#  {'id': 'id-230',
#   'sparse_values': {'indices': [7687, 7637, 2090, 5173, 6705],
#    'values': [0.10246926415865358,
#     0.26119760905220846,
#     0.4964862134503532,
#     0.5128030113278631,
#     0.6417245284037377]},
#   'metadata': {'title': 'economic on saturday the times',
#    'original': 'THE ECONOMIC TIMES ON SATURDAY'}},
#  {'id': 'id-231',
#   'sparse_values': {'indices': [7687, 614],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'ascent times', 'original': 'TIMES ASCENT'}},
#  {'id': 'id-232',
#   'sparse_values': {'indices': [7687, 4999, 3094],
# ...
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'shilpi times', 'original': 'SHILPI TIMES'}},
#  {'id': 'id-927',
#   'sparse_values': {'indices': [7687, 6572],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'sangrah times', 'original': 'SANGRAH TIMES'}},
#  {'id': 'id-928',
#   'sparse_values': {'indices': [7687, 5149, 7637, 657],
#    'values': [0.14181005696588952,
#     0.3303318777440299,
#     0.3614786162775401,
#     0.8602929549075183]},
#   'metadata': {'title': 'astrology of the times',
#    'original': 'THE TIMES OF ASTROLOGY'}},
#  {'id': 'id-929',
#   'sparse_values': {'indices': [7687, 7508],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'tanatan times', 'original': 'TANATAN TIMES'}},
#  {'id': 'id-930',
#   'sparse_values': {'indices': [7687, 2666],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'gujral times', 'original': 'GUJRAL TIMES'}},
#  {'id': 'id-931',
#   'sparse_values': {'indices': [7687, 798, 2739],
#    'values': [0.11941828304146494, 0.7244529040167842, 0.6789015123985781]},
#   'metadata': {'title': 'bajaj hamara times',
#    'original': 'HAMARA BAJAJ TIMES'}},
#  {'id': 'id-932',
#   'sparse_values': {'indices': [7687, 6601],
#    'values': [0.17597169272937793, 0.9843952272120975]},
#   'metadata': {'title': 'sansar times', 'original': 'SANSAR TIMES'}},
#  {'id': 'id-933',
#   'sparse_values': {'indices': [7687, 418, 7769, 7732, 7943],
#    'values': [0.0927967161536858,
#     0.3235956176674261,
#     0.47934919809815574,
#     0.6067956132842176,
#     0.5373063145722508]},
#   'metadata': {'title': 'and times tour travel uttarakhand',
#    'original': 'UTTARAKHAND TOUR AND TRAVEL TIMES'}},
#  {'id': 'id-934',
#   'sparse_values': {'indices': [7687, 1479, 6807],
#    'values': [0.13442194180573688, 0.7006892112631589, 0.7006892112631589]},
#   'metadata': {'title': 'civil services times',
#    'original': 'CIVIL SERVICES TIMES'}},
#  {'id': 'id-935',
#   'sparse_values': {'indices': [7687, 2233, 7869],
#    'values': [0.1173063888609598, 0.6307553649485161, 0.7670638048565879]},
#   'metadata': {'title': 'export times umci', 'original': 'UMCI EXPORT TIMES'}},
#  {'id': 'id-936',
#   'sparse_values': {'indices': [7687, 2773, 5167, 6384],
#    'values': [0.09377427231967472,
#     0.5546201718405219,
#     0.5546201718405219,
#     0.6131878307876757]},
#   'metadata': {'title': 'hari om sadguru times',
#    'original': 'HARI OM SADGURU TIMES'}},
#  {'id': 'id-937',
#   'sparse_values': {'indices': [7687, 5127, 5019],
#    'values': [0.1173063888609598, 0.6307553649485161, 0.7670638048565879]},
#   'metadata': {'title': 'nightingale nursing times',
#    'original': 'NIGHTINGALE NURSING TIMES'}},
#  {'id': 'id-938',
#   'sparse_values': {'indices': [7687, 6348],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'saaol times', 'original': 'SAAOL TIMES'}},
#  {'id': 'id-939',
#   'sparse_values': {'indices': [7687, 6810],
#    'values': [0.17018777331851725, 0.9854116509423282]},
#   'metadata': {'title': 'seva times', 'original': 'SEVA TIMES'}},
#  {'id': 'id-940',
#   'sparse_values': {'indices': [7687, 7637, 5173, 4612, 7595],
#    'values': [0.09726537710217456,
#     0.24793272549819434,
#     0.4867603830813992,
#     0.5362990570235882,
#     0.6360160854430245]},
#   'metadata': {'title': 'modern on television the times',
#    'original': 'THE MODERN TIMES ON TELEVISION'}},
#  {'id': 'id-941',
#   'sparse_values': {'indices': [7687, 4142],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'lpg times', 'original': 'LPG TIMES'}},
#  {'id': 'id-942',
#   'sparse_values': {'indices': [7687, 2703],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'gyaneshwari times', 'original': 'GYANESHWARI TIMES'}},
#  {'id': 'id-943',
#   'sparse_values': {'indices': [7687, 6116],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'ration times', 'original': 'RATION TIMES'}},
#  {'id': 'id-944',
#   'sparse_values': {'indices': [7687, 4462],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'mave times', 'original': 'MAVE TIMES'}},
#  {'id': 'id-945',
#   'sparse_values': {'indices': [7687, 2486],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'gayatri times', 'original': 'GAYATRI TIMES'}},
#  {'id': 'id-946',
#   'sparse_values': {'indices': [7687, 7637, 1633],
#    'values': [0.18885899326584615, 0.48140794114290764, 0.8559080995452478]},
#   'metadata': {'title': 'crime the times', 'original': 'THE CRIME TIMES'}},
#  {'id': 'id-947',
#   'sparse_values': {'indices': [4091, 4012],
#    'values': [0.6396853515892875, 0.7686368784816988]},
#   'metadata': {'title': 'lawtimes local', 'original': 'LOCAL LAWTIMES'}},
#  {'id': 'id-948',
#   'sparse_values': {'indices': [7687, 1528],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'comdex times', 'original': 'COMDEX TIMES'}},
#  {'id': 'id-949',
#   'sparse_values': {'indices': [7687, 8338],
#    'values': [0.16671221505815761, 0.986005597017787]},
#   'metadata': {'title': 'times women', 'original': 'WOMEN TIMES'}},
#  {'id': 'id-950',
#   'sparse_values': {'indices': [7687, 1919, 2435],
#    'values': [0.11141355040564307, 0.7285306684193379, 0.6758920667965278]},
#   'metadata': {'title': 'diagnostic ganesh times',
#    'original': 'GANESH DIAGNOSTIC TIMES'}},
#  {'id': 'id-951',
#   'sparse_values': {'indices': [7687, 1793, 6249],
#    'values': [0.12220088705504348, 0.5886900447581328, 0.799068817064981]},
#   'metadata': {'title': 'delhi richie times',
#    'original': 'RICHIE DELHI TIMES'}},
#  {'id': 'id-952',
#   'sparse_values': {'indices': [7687, 5610],
#    'values': [0.15768042072751778, 0.987490194847115]},
#   'metadata': {'title': 'pooja times', 'original': 'POOJA TIMES'}},
#  {'id': 'id-953',
#   'sparse_values': {'indices': [7687, 1633, 3129],
#    'values': [0.13301528799016155, 0.6028246809187656, 0.7867079110038763]},
#   'metadata': {'title': 'crime investigation times',
#    'original': 'CRIME INVESTIGATION TIMES'}},
#  {'id': 'id-954',
#   'sparse_values': {'indices': [7687, 2125],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'ele times', 'original': 'ELE TIMES'}},
#  {'id': 'id-955',
#   'sparse_values': {'indices': [7687, 3390],
#    'values': [0.16264438796429254, 0.9866847536390337]},
#   'metadata': {'title': 'jewellery times', 'original': 'JEWELLERY TIMES'}},
#  {'id': 'id-956',
#   'sparse_values': {'indices': [7687, 6766],
#    'values': [0.17323962484789424, 0.984879704523634]},
#   'metadata': {'title': 'security times', 'original': 'SECURITY TIMES'}},
#  {'id': 'id-957',
#   'sparse_values': {'indices': [7687, 6463, 4257],
#    'values': [0.14025067575612982, 0.6307119226471793, 0.7632379829258024]},
#   'metadata': {'title': 'mail samachar times',
#    'original': 'SAMACHAR MAIL TIMES'}},
#  {'id': 'id-958',
#   'sparse_values': {'indices': [7687, 266],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'airport times', 'original': 'AIRPORT TIMES'}},
#  {'id': 'id-959',
#   'sparse_values': {'indices': [7687, 1599],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'coop times', 'original': 'COOP TIMES'}},
#  {'id': 'id-960',
#   'sparse_values': {'indices': [7687, 8190],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'times visharad', 'original': 'VISHARAD TIMES'}},
#  {'id': 'id-961',
#   'sparse_values': {'indices': [7687, 3494, 1753],
#    'values': [0.12082621258062533, 0.642515403515548, 0.7566868457946617]},
#   'metadata': {'title': 'daya jyoti times', 'original': 'DAYA JYOTI TIMES'}},
#  {'id': 'id-962',
#   'sparse_values': {'indices': [7687, 1479, 7880],
#    'values': [0.12405962401198561, 0.6466744858081819, 0.7526096724695533]},
#   'metadata': {'title': 'civil times unique',
#    'original': 'UNIQUE CIVIL TIMES'}},
#  {'id': 'id-963',
#   'sparse_values': {'indices': [7687, 2923],
#    'values': [0.16671221505815761, 0.986005597017787]},
#   'metadata': {'title': 'hosiery times', 'original': 'HOSIERY TIMES'}},
#  {'id': 'id-964',
#   'sparse_values': {'indices': [7687, 4789, 1943],
#    'values': [0.1219206016662644, 0.6820304818211329, 0.7210893070599296]},
#   'metadata': {'title': 'dilli nai times', 'original': 'NAI DILLI TIMES'}},
#  {'id': 'id-965',
#   'sparse_values': {'indices': [7687, 6486, 6287],
#    'values': [0.11612224854506535, 0.6402715359727421, 0.7593207383022959]},
#   'metadata': {'title': 'rohini samarpan times',
#    'original': 'ROHINI SAMARPAN TIMES'}},
#  {'id': 'id-966',
#   'sparse_values': {'indices': [7687, 1521],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'colony times', 'original': 'COLONY TIMES'}},
#  {'id': 'id-967',
#   'sparse_values': {'indices': [7687, 3353, 5446],
#    'values': [0.12133859071033304, 0.7598956676433478, 0.6386200127629112]},
#   'metadata': {'title': 'jat patrika times', 'original': 'JAT TIMES PATRIKA'}},
#  {'id': 'id-968',
#   'sparse_values': {'indices': [7687, 7637, 1460],
#    'values': [0.16243690362742874, 0.4140571438439994, 0.8956399577797337]},
#   'metadata': {'title': 'christian the times',
#    'original': 'THE CHRISTIAN TIMES'}},
#  {'id': 'id-969',
#   'sparse_values': {'indices': [7687, 5334, 6109],
#    'values': [0.11219646414038684, 0.7026421398672281, 0.7026421398672281]},
#   'metadata': {'title': 'paramhans rastriya times',
#    'original': 'RASTRIYA PARAMHANS TIMES'}},
#  {'id': 'id-970',
#   'sparse_values': {'indices': [7687, 3652],
#    'values': [0.15768042072751778, 0.987490194847115]},
#   'metadata': {'title': 'kartavya times', 'original': 'KARTAVYA TIMES'}},
#  {'id': 'id-971',
#   'sparse_values': {'indices': [7687, 1901],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'dhiran times', 'original': 'DHIRAN TIMES'}},
#  {'id': 'id-972',
#   'sparse_values': {'indices': [7687, 4097],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'logistics times', 'original': 'LOGISTICS TIMES'}},
#  {'id': 'id-973',
#   'sparse_values': {'indices': [7687, 4458],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'mauka times', 'original': 'MAUKA TIMES'}},
#  {'id': 'id-974',
#   'sparse_values': {'indices': [7687, 4136, 6906],
#    'values': [0.10751044612121914, 0.703008358405082, 0.703008358405082]},
#   'metadata': {'title': 'lotary sharthy times',
#    'original': 'SHARTHY LOTARY TIMES'}},
#  {'id': 'id-975',
#   'sparse_values': {'indices': [7687, 1586],
#    'values': [0.18284246242211483, 0.9831422246732247]},
#   'metadata': {'title': 'consumer times', 'original': 'CONSUMER TIMES'}},
#  {'id': 'id-976',
#   'sparse_values': {'indices': [7687, 8174, 5397],
#    'values': [0.11644767182766251, 0.674248744822153, 0.7292657744825738]},
#   'metadata': {'title': 'parwana times vir', 'original': 'VIR PARWANA TIMES'}},
#  {'id': 'id-977',
#   'sparse_values': {'indices': [7687, 7637, 2233],
#    'values': [0.16572652855390255, 0.42244250869001937, 0.8911100070053951]},
#   'metadata': {'title': 'export the times', 'original': 'THE EXPORT TIMES'}},
#  {'id': 'id-978',
#   'sparse_values': {'indices': [7687, 4585, 1993],
#    'values': [0.12967916147810768, 0.6759669452229647, 0.7254322877045577]},
#   'metadata': {'title': 'divya mirror times',
#    'original': 'DIVYA MIRROR TIMES'}},
#  {'id': 'id-979',
#   'sparse_values': {'indices': [7687, 7637, 4484, 6589],
#    'values': [0.1240004655397443,
#     0.3160813672887759,
#     0.5307181900404272,
#     0.7765659383201131]},
#   'metadata': {'title': 'medical sanjivani the times',
#    'original': 'THE SANJIVANI MEDICAL TIMES'}},
#  {'id': 'id-980',
#   'sparse_values': {'indices': [7687, 6426, 7244, 7338],
#    'values': [0.09936491008909572,
#     0.5089066312473043,
#     0.5558527154392442,
#     0.6497448838231239]},
#   'metadata': {'title': 'sai sri sumiran times',
#    'original': 'SRI SAI SUMIRAN TIMES'}},
#  {'id': 'id-981',
#   'sparse_values': {'indices': [7687, 7035, 65, 805],
#    'values': [0.09758822232387322,
#     0.4579934561360277,
#     0.6381271629942179,
#     0.6111564912926913]},
#   'metadata': {'title': 'aashirwad balaji shri times',
#    'original': 'SHRI BALAJI AASHIRWAD TIMES'}},
#  {'id': 'id-982',
#   'sparse_values': {'indices': [7687, 2493],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'geeta times', 'original': 'GEETA TIMES'}},
#  {'id': 'id-983',
#   'sparse_values': {'indices': [7687, 7637, 6939],
#    'values': [0.14106098818864146, 0.35956921470976927, 0.9223945887982236]},
#   'metadata': {'title': 'shephard the times',
#    'original': 'THE SHEPHARD TIMES'}},
#  {'id': 'id-984',
#   'sparse_values': {'indices': [7687, 4025],
#    'values': [0.16671221505815761, 0.986005597017787]},
#   'metadata': {'title': 'leader times', 'original': 'LEADER TIMES'}},
#  {'id': 'id-985',
#   'sparse_values': {'indices': [7687, 1562, 5840],
#    'values': [0.12349035857839966, 0.8075006419857206, 0.5767953229099795]},
#   'metadata': {'title': 'complaint public times',
#    'original': 'PUBLIC COMPLAINT TIMES'}},
#  {'id': 'id-986',
#   'sparse_values': {'indices': [7687, 4008, 2110],
#    'values': [0.12892146585044564, 0.5222123705820465, 0.8430145287324837]},
#   'metadata': {'title': 'egjim law times', 'original': 'EGJIM LAW TIMES'}},
#  {'id': 'id-987',
#   'sparse_values': {'indices': [7687, 3040, 2286],
#    'values': [0.14914222500846805, 0.3246003532428169, 0.9340188474512502]},
#   'metadata': {'title': 'farmer indian times',
#    'original': 'INDIAN FARMER TIMES'}},
#  {'id': 'id-988',
#   'sparse_values': {'indices': [7687, 7035, 4174, 7990],
#    'values': [0.09758822232387322,
#     0.4579934561360277,
#     0.6381271629942179,
#     0.6111564912926913]},
#   'metadata': {'title': 'madh shri times valmiki',
#    'original': 'SHRI MADH VALMIKI TIMES'}},
#  {'id': 'id-989',
#   'sparse_values': {'indices': [7687, 7149],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'sobti times', 'original': 'SOBTI TIMES'}},
#  {'id': 'id-990',
#   'sparse_values': {'indices': [7687, 2640, 2079],
#    'values': [0.11941828304146494, 0.6789015123985781, 0.7244529040167842]},
#   'metadata': {'title': 'earth green times', 'original': 'GREEN EARTH TIMES'}},
#  {'id': 'id-991',
#   'sparse_values': {'indices': [7687, 2566],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'gobar times', 'original': 'GOBAR TIMES'}},
#  {'id': 'id-992',
#   'sparse_values': {'indices': [7687, 3226, 555],
#    'values': [0.1173063888609598, 0.6307553649485161, 0.7670638048565879]},
#   'metadata': {'title': 'arhat jain times', 'original': 'ARHAT JAIN TIMES'}},
#  {'id': 'id-993',
#   'sparse_values': {'indices': [7687], 'values': [1.0]},
#   'metadata': {'title': 'b k times', 'original': 'B K TIMES'}},
#  {'id': 'id-994',
#   'sparse_values': {'indices': [7687, 632, 2909],
#    'values': [0.11543030026763307, 0.6457233825321229, 0.7547961042767759]},
#   'metadata': {'title': 'asian homieopathic times',
#    'original': 'ASIAN HOMIEOPATHIC TIMES'}},
#  {'id': 'id-995',
#   'sparse_values': {'indices': [7687, 4999, 8352],
#    'values': [0.1797214279202095, 0.5467750168813638, 0.8177635900801071]},
#   'metadata': {'title': 'news times world', 'original': 'WORLD NEWS TIMES'}},
#  {'id': 'id-996',
#   'sparse_values': {'indices': [7687, 3497],
#    'values': [0.16671221505815761, 0.986005597017787]},
#   'metadata': {'title': 'jyotish times', 'original': 'JYOTISH TIMES'}},
#  {'id': 'id-997',
#   'sparse_values': {'indices': [7687, 6257],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'ripul times', 'original': 'RIPUL TIMES'}},
#  {'id': 'id-998',
#   'sparse_values': {'indices': [7687, 6463, 7608],
#    'values': [0.12501804172099845, 0.5622102641169625, 0.8174901272589059]},
#   'metadata': {'title': 'samachar tent times',
#    'original': 'TENT SAMACHAR TIMES'}},
#  {'id': 'id-999',
#   'sparse_values': {'indices': [7687, 7263],
#    'values': [0.15117158298878694, 0.9885075379058392]},
#   'metadata': {'title': 'stationery times', 'original': 'STATIONERY TIMES'}},
#  ...]

# %%
embedding_size = len(vectorizer.vocabulary_)
print("TF-IDF Embedding Size:", embedding_size)
# Out:
# TF-IDF Embedding Size: 8468

# %%
from pinecone import Pinecone
pc = Pinecone(api_key=api_key)
index_name = "tfidf"
index = pc.Index(index_name)

# %%
def batch_upsert(index, records, batch_size=1000):
    for i in range(0, len(records), batch_size):
        batch = records[i:i + batch_size]
        index.upsert(batch)

# Example usage
batch_upsert(index, records)

# %%
import joblib

# Save to a file
joblib.dump(vectorizer, "tfidf_vectorizer.pkl")
# Out:
# ['tfidf_vectorizer.pkl']

# %%
query = "Mahila"
sorted_query = ' '.join(sorted(query.lower().split()))

query_vec = vectorizer.transform([sorted_query])

sparse_query = {
    "indices": query_vec.indices.tolist(),
    "values": query_vec.data.tolist()
}

results = index.query(top_k=15, sparse_vector=sparse_query, include_metadata=True)

for match in results["matches"]:
    print(f"Score: {match['score']:.4f}")
    print("Match:", match["metadata"]["original"])
# Out:
# Score: 0.9844
# Match: MAHILA TIMES
# Score: 0.8363
# Match: MAHILA JAGRAN
# Score: 0.8201
# Match: MAHILA KI AWAZ
# Score: 0.7634
# Match: MAHILA KI AAWAZ
# Score: 0.6959
# Match: MAHILA PRAGATI TIMES
# Score: 0.6820
# Match: MAHILA MORCHA TIMES
# Score: 0.6457
# Match: MAHILA ABADH TIMES
# Score: 0.0000
# Match: HOSPET TIMES
# Score: 0.0000
# Match: ABHI TAK CRIME TIMES
# Score: 0.0000
# Match: THE JOURNAL OF THE INDIAN ACADEMY OF PHILOSOPHY
# Score: 0.0000
# Match: AMALNER TIMES
# Score: 0.0000
# Match: STATE NEWS TIMES
# Score: 0.0000
# Match: BHADRA TIMES
# Score: 0.0000
# Match: LOK PRIYA DILLI TIMES
# Score: 0.0000
# Match: THE MISSILE TIMES
